# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1. Porcentaje de reviews modificadas por juego

# %%
df_avg = pd.read_csv("porcentajeModificadas1.csv")

# %%
df_avg.plot.bar(x='app_name')
# Out:
# <AxesSubplot:xlabel='app_name'>
